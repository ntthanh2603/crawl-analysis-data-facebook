# %% [markdown]
# ## So sánh Fanpage của 2 đội bóng Liverpool và Manchester United

# %% [markdown]
# #### Chuẩn bị dữ liệu

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv('C:/Users/Admin/aim/project_analysis_data_facebook/data/data_ready.csv')
df_lp = df1[['post_text','comments', 'reaction_count', 'shares']]
df2 = pd.read_csv('C:/Users/Admin/aim/project_analysis_data_facebook/data/manchesterunited.csv')
df_mu = df2[['post_text','comments', 'reaction_count', 'shares']]
print('Ok')
# Out:
# Ok

# %% [markdown]
# #### So sánh số lượt bình luận mỗi bài viết

# %%
a_lp = df_lp['comments'].mean()
a_mu = df_mu['comments'].mean()
print(a_lp, a_mu)
# Out:
# 230.8673469387755 1222.88

# %%
a_lp1 = df_lp['comments'].median()
a_mu1 = df_mu['comments'].median()
print(a_lp1, a_mu1)
# Out:
# 116.5 317.0

# %%
categories = ['Liverpool', 'ManchesterUnited']
values = [a_lp1, a_mu1]

plt.bar(categories, values, color=['pink', 'red'])

plt.title('So sánh comments giữa Liverpool và MU')
plt.xlabel('Đội bóng')
plt.ylabel('Độ chênh lệch số lượt comments của các bài đăng')

plt.show()

# %% [markdown]
# #### So sánh sô lượt thả rections

# %%
b_lp = df_lp['reaction_count'].mean()
b_mu = df_mu['reaction_count'].mean()
print(b_lp, b_mu)
# Out:
# 23034.45918367347 46342.44

# %%
b_lp1 = df_lp['reaction_count'].median()
b_mu1 = df_mu['reaction_count'].median()
print(b_lp1, b_mu1)
# Out:
# 13180.5 14451.0

# %%
categories = ['Liverpool', 'ManchesterUnited']
values = [b_lp, b_mu]

plt.bar(categories, values, color=['blue', 'orange'])
A
plt.title('So sánh reaction_count giữa Liverpool và MU')
plt.xlabel('Đội bóng')
plt.ylabel('Trung bình reaction_count')

plt.show()

# %% [markdown]
# #### So sánh số lượt chia sẻ

# %%
c_lp = df_lp['shares'].mean()
c_mu = df_mu['shares'].mean()
print(c_lp, c_mu)
# Out:
# 224.74489795918367 963.6

# %%
c_lp1 = df_lp['shares'].median()
c_mu1 = df_mu['shares'].median()
print(c_lp1, c_mu1)
# Out:
# 104.0 59.5

# %%
categories = ['Liverpool', 'ManchesterUnited']
values = [c_lp, c_mu]

plt.bar(categories, values, color=['pink', 'red'])

plt.title('So sánh shares giữa Liverpool và MU')
plt.xlabel('Đội bóng')
plt.ylabel('Trung bình shares')

plt.show()
