# %% [markdown]
# ## Tách Reactions

# %% [markdown]
# ### Đọc file Lp_select_column.csv

# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('C:/Users/Admin/aim/project_analysis_data_facebook/data/Lp_select_column.csv')

# %%
df
# Out:
#          post_id                                          post_text  \
# 0   8.992690e+14  🔴🗣️ Emile Heskey is the latest to tell the tal...
# 1   8.992110e+14  Back-to-back PFA Premier League Fans’ Player o...
# 2   8.990810e+14  Ryan's first goal in Red 😍\n\nA look back at o...
# 3   8.991520e+14  Well in, Robbo 👏 #Euro2024 🔜\n\nVâng, Robbo 👏 ...
# 4   8.991290e+14  Two years ago today... Diogo 😲\n\nNgày này hai...
# ..           ...                                                ...
# 93  8.948540e+14  "I really thank him because in this period he ...
# 94  8.948430e+14  Jürgen Klopp confirmed Joe Gomez and Ibrahima ...
# 95  8.948350e+14                 Anfield remembers.\n\nAnfield nhớ.
# 96  8.944540e+14               Good morning 😁🔴\n\nChào buổi sáng 😁🔴
# 97  8.955110e+14  Big Virg against Brentford 🔝\n\nBig Virg chống...
#
#                 time  comments  \
# 0    11/21/2023 0:01        16
# 1   11/20/2023 22:00        83
# 2   11/20/2023 21:10        49
# 3   11/20/2023 20:01       150
# 4   11/20/2023 19:20       211
# ..               ...       ...
# 93  11/13/2023 17:03        97
# 94  11/13/2023 16:39       114
# 95  11/13/2023 16:24       149
# 96  11/13/2023 15:13       417
# 97  11/14/2023 18:58       631
#
#                                         comments_full  shares  \
# 0   [{'comment_id': '1186163892166613', 'comment_u...     101
# 1   [{'comment_id': '277210241476921', 'comment_ur...      31
# 2   [{'comment_id': '388506910181825', 'comment_ur...      53
# 3   [{'comment_id': '314996431472511', 'comment_ur...      61
# 4   [{'comment_id': '1028198778438522', 'comment_u...     211
# ..                                                ...     ...
# 93  [{'comment_id': '1120275918934925', 'comment_u...      43
# 94  [{'comment_id': '707770537958734', 'comment_ur...      34
# 95  [{'comment_id': '7303758222967701', 'comment_u...     309
# 96  [{'comment_id': '1483340398900267', 'comment_u...     124
# 97  [{'comment_id': '304499032539488', 'comment_ur...     727
#
#                                             reactions  reaction_count
# 0   {'thích': 982, 'yêu thích': 183, 'thương thươn...            1175
# 1   {'thích': 3638, 'yêu thích': 902, 'haha': 1, '...            4594
# 2   {'thích': 4072, 'yêu thích': 1022, 'haha': 3, ...            5157
# 3   {'thích': 12735, 'yêu thích': 3112, 'haha': 19...           16019
# 4   {'thích': 11699, 'yêu thích': 2506, 'haha': 45...           14403
# ..                                                ...             ...
# 93  {'thích': 11518, 'yêu thích': 1523, 'haha': 9,...           13139
# 94  {'thích': 7779, 'yêu thích': 934, 'haha': 3, '...            8853
# 95  {'thích': 13364, 'yêu thích': 2481, 'haha': 8,...           16050
# 96  {'thích': 26432, 'yêu thích': 7266, 'haha': 15...           34107
# 97  {'thích': 39460, 'yêu thích': 6610, 'haha': 12...           46476
#
# [98 rows x 8 columns]

# %% [markdown]
# ### Tạo 1 list chứa các dictionary của các loại reaction của từng post và lưu vào 1 list

# %%
react_list = []

for react_str in df.reactions:
    react_dict = ast.literal_eval(react_str)
    react_list.append(react_dict)

# %% [markdown]
# ### Tạo dataframe từ react_list

# %%
df_reactions = pd.DataFrame(react_list)
df_reactions
# Out:
#     thích  yêu thích  thương thương  haha   wow  buồn  phẫn nộ
# 0     982        183             10   NaN   NaN   NaN      NaN
# 1    3638        902             49   1.0   4.0   NaN      NaN
# 2    4072       1022             55   3.0   4.0   1.0      NaN
# 3   12735       3112            146  19.0   6.0   1.0      NaN
# 4   11699       2506            125  45.0  26.0   1.0      1.0
# ..    ...        ...            ...   ...   ...   ...      ...
# 93  11518       1523             77   9.0   7.0   2.0      3.0
# 94   7779        934             85   3.0   9.0  39.0      4.0
# 95  13364       2481            174   8.0  13.0   7.0      3.0
# 96  26432       7266            385  15.0   6.0   2.0      1.0
# 97  39460       6610            353  12.0  38.0   1.0      2.0
#
# [98 rows x 7 columns]

# %% [markdown]
# ### Thay thế các giá trị NaN bằng 0

# %%
df_reactions = df_reactions.fillna(0)

# %% [markdown]
# ### Bỏ thuộc tính reactions cũ

# %%
no_react_df = df.drop(['reactions'], axis = 1)

# %% [markdown]
# ### Thay thuộc tính reactions bằng dataframe df_reactions

# %%
new_df = pd.concat([no_react_df, df_reactions], axis = 1)

# %%
new_df
# Out:
#          post_id                                          post_text  \
# 0   8.992690e+14  🔴🗣️ Emile Heskey is the latest to tell the tal...
# 1   8.992110e+14  Back-to-back PFA Premier League Fans’ Player o...
# 2   8.990810e+14  Ryan's first goal in Red 😍\n\nA look back at o...
# 3   8.991520e+14  Well in, Robbo 👏 #Euro2024 🔜\n\nVâng, Robbo 👏 ...
# 4   8.991290e+14  Two years ago today... Diogo 😲\n\nNgày này hai...
# ..           ...                                                ...
# 93  8.948540e+14  "I really thank him because in this period he ...
# 94  8.948430e+14  Jürgen Klopp confirmed Joe Gomez and Ibrahima ...
# 95  8.948350e+14                 Anfield remembers.\n\nAnfield nhớ.
# 96  8.944540e+14               Good morning 😁🔴\n\nChào buổi sáng 😁🔴
# 97  8.955110e+14  Big Virg against Brentford 🔝\n\nBig Virg chống...
#
#                 time  comments  \
# 0    11/21/2023 0:01        16
# 1   11/20/2023 22:00        83
# 2   11/20/2023 21:10        49
# 3   11/20/2023 20:01       150
# 4   11/20/2023 19:20       211
# ..               ...       ...
# 93  11/13/2023 17:03        97
# 94  11/13/2023 16:39       114
# 95  11/13/2023 16:24       149
# 96  11/13/2023 15:13       417
# 97  11/14/2023 18:58       631
#
#                                         comments_full  shares  reaction_count  \
# 0   [{'comment_id': '1186163892166613', 'comment_u...     101            1175
# 1   [{'comment_id': '277210241476921', 'comment_ur...      31            4594
# 2   [{'comment_id': '388506910181825', 'comment_ur...      53            5157
# 3   [{'comment_id': '314996431472511', 'comment_ur...      61           16019
# 4   [{'comment_id': '1028198778438522', 'comment_u...     211           14403
# ..                                                ...     ...             ...
# 93  [{'comment_id': '1120275918934925', 'comment_u...      43           13139
# 94  [{'comment_id': '707770537958734', 'comment_ur...      34            8853
# 95  [{'comment_id': '7303758222967701', 'comment_u...     309           16050
# 96  [{'comment_id': '1483340398900267', 'comment_u...     124           34107
# 97  [{'comment_id': '304499032539488', 'comment_ur...     727           46476
#
#     thích  yêu thích  thương thương  haha   wow  buồn  phẫn nộ
# 0     982        183             10   0.0   0.0   0.0      0.0
# 1    3638        902             49   1.0   4.0   0.0      0.0
# 2    4072       1022             55   3.0   4.0   1.0      0.0
# 3   12735       3112            146  19.0   6.0   1.0      0.0
# 4   11699       2506            125  45.0  26.0   1.0      1.0
# ..    ...        ...            ...   ...   ...   ...      ...
# 93  11518       1523             77   9.0   7.0   2.0      3.0
# 94   7779        934             85   3.0   9.0  39.0      4.0
# 95  13364       2481            174   8.0  13.0   7.0      3.0
# 96  26432       7266            385  15.0   6.0   2.0      1.0
# 97  39460       6610            353  12.0  38.0   1.0      2.0
#
# [98 rows x 14 columns]

# %% [markdown]
# ### Lưu lại vào file Lp_divide_reactions.csv

# %%
new_df.to_csv('C:/Users/Admin/aim/project_analysis_data_facebook/data/Lp_select_column.csv', index=False)
