# %%
# %pip install facebook_scraper pandas numpy
# Out:
# ...
#
# ...

# %%
from facebook_scraper import *
import pandas as pd
import numpy as np

# %%
FANPAGE_LINK ="manchesterunited"
FOLDER_PATH = "C:/Users/Admin/aim/project_analysis_data_facebook/manchester_united/data/"
COOKIE_PATH = "C:/Users/Admin/aim/project_analysis_data_facebook/manchester_united/data/www.facebook.com_cookies.txt"
Crawl_data = ['text', 'time', 'reaction_count', 'reactions', 'comments', 'shares']

PAGES_NUMBER = 150

# %%
post_list = []
run = 0
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH):
    
    test = True
    for i in range(len(Crawl_data)):
        if post.get(Crawl_data[i]) == 0:
            test = False
            print('error data')
            continue
    if test == True:
        post_list.append({
                        'post_id' : post.get('post_it'),
                        'text' : post.get('text'), 
                        'time' : post.get('time'), 
                        'reaction_count' : post.get('reaction_count'),
                        'reactions' : post.get('reactions'), 
                        'comments' : post.get('comments'), 
                        'comments_full' : post.get('comments_full'),
                        'shares' : post.get('shares') })
        print('Good data')

# %%
post_list
# Out:
# [{'text': 'Simply outrageous 🤯🤸\u200d♂️ Remington for Men UK\n\nĐơn giản là quá đáng 🤯 🤸 ♂️ Remington for Men UK',
#   'time': datetime.datetime(2023, 11, 27, 18, 1, 49),
#   'reaction_count': 6248,
#   'reactions': {'thích': 4649,
#    'yêu thích': 1500,
#    'haha': 3,
#    'wow': 17,
#    'thương thương': 79},
#   'comments': 147,
#   'shares': 205},
#  {'text': "Three goals, big saves and an effort you'll want to watch over and over again ▶️🔥\n\nBa bàn thắng, tiết kiệm lớn và nỗ lực mà bạn sẽ muốn xem đi xem lại nhiều lần ▶️🔥\n\nMANUTD.COM\nWATCH | Extended highlights: Everton 0 United 3",
#   'time': datetime.datetime(2023, 11, 27, 17, 9, 1),
#   'reaction_count': 2093,
#   'reactions': {'thích': 1803,
#    'yêu thích': 262,
#    'haha': 3,
#    'wow': 1,
#    'thương thương': 24},
#   'comments': 38,
#   'shares': 11},
#  {'text': 'Poetry in motion 😍\n\nWhich overhead kick do you prefer, Reds?\n\nThơ ca chuyển động 😍\n\nBạn thích cú đá trên đầu nào hơn, Quỷ đỏ?',
# ...

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".csv"
post_df_full.to_csv(path, index=False)
print(path)
# Out:
# C:/Users/Admin/aim/project_analysis_data_facebook/manchester_united/data/manchesterunited.csv

# %%
df = pd.read_csv('./data/manchesterunited.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   text            108 non-null    object
#  1   time            115 non-null    object
#  2   reaction_count  115 non-null    int64
#  3   reactions       115 non-null    object
#  4   comments        115 non-null    int64
#  5   shares          115 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 5.5+ KB
